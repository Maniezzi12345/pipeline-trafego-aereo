# %%
import sys
sys.path.append("..")

from extract.api import (
    autenticacao_url,
    buscar_voos_brasil,
    buscar_chegadas_voos,
    buscar_partidas_voos,
    intervalo_de_tempos_voos,
    TOKEN_URL,
    LOCALIZACAO_URL,
    INTERVALO_URL
)

token     = autenticacao_url(TOKEN_URL)
local     = buscar_voos_brasil(token, LOCALIZACAO_URL)
chegadas = buscar_chegadas_voos(token, 1753484400, 1753570800)
partidas  = buscar_partidas_voos(token, 1753484400, 1753570800)
intervalo = intervalo_de_tempos_voos(token, INTERVALO_URL)

print(local["states"])
print(chegadas)
# print(partidas)
# print(intervalo)
# Out:
# bug aqui
# SBGR: 378 voos
# bug aqui
# SBGL: 218 voos
# bug aqui
# SBBR: 135 voos
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      14
#      15 token     = autenticacao_url(TOKEN_URL)
#      16 local     = buscar_voos_brasil(token, LOCALIZACAO_URL)
#      17 chegadas = buscar_chegadas_voos(token, 1753484400, 1753570800)
# ---> 18 partidas  = buscar_partidas_voos(token, 1753484400, 1753570800)
#      19 intervalo = intervalo_de_tempos_voos(token, INTERVALO_URL)
#      20
#      21 print(local["states"])
#
# TypeError: buscar_partidas_voos() takes 2 positional arguments but 3 were given

# %%
import pandas as pd

COLUNAS_VOOS = [
    "icao24",
    "callsign",
    "origin_country",
    "time_position",
    "last_contact",
    "longitude",
    "latitude",
    "baro_altitude",
    "on_ground",
    "velocity",
    "true_track",
    "vertical_rate",
    "sensors",
    "geo_altitude",
    "squawk",
    "spi",
    "position_source"
]

df_voos = pd.DataFrame(local["states"], columns=COLUNAS_VOOS)
print(df_voos.shape)
df_voos.head(200)
# Out:
# (152, 17)
#      icao24  callsign origin_country  time_position  last_contact  longitude  \
# 0    e80268  ARE4907           Chile     1785367445    1785367445   -46.1940
# 1    e80210  LPE2935           Chile     1785367442    1785367444   -46.3703
# 2    e07584  ARG1364       Argentina     1785367081    1785367311   -63.6396
# 3    e49eef  GLO1350          Brazil     1785367445    1785367445   -45.6786
# 4    e49ef4  GLO2178          Brazil     1785367445    1785367445   -44.9652
# ..      ...       ...            ...            ...           ...        ...
# 147  0c2167  CMP800           Panama     1785367409    1785367409   -68.6159
# 148  0c2166  CMP283           Panama     1785367446    1785367446   -72.2762
# 149  4b18e4  SWW1C       Switzerland     1785367445    1785367445   -69.5729
# 150  0c2083  CMP207           Panama     1785367445    1785367445   -72.4787
# 151  e94c88  BOV777          Bolivia     1785367445    1785367445   -57.8627
#
#      latitude  baro_altitude  on_ground  velocity  true_track  vertical_rate  \
# 0    -23.3594        1485.90      False     68.69      253.47          -0.65
# 1    -23.4073        1196.34      False     69.33      253.18          -2.93
# 2    -28.2739       11582.40      False    221.69      317.16           0.00
# 3    -23.4712        6446.52      False    207.63       61.59          10.73
# 4    -23.2716        9448.80      False    274.77       76.80          -0.33
# ..        ...            ...        ...       ...         ...            ...
# 147   -4.6447       10668.00      False    245.99      136.53           0.00
# 148   -4.1688       10668.00      False    239.41      159.89           0.00
# 149   -4.8277       12496.80      False    230.28       45.63           0.00
# 150   -3.2752       10668.00      False    243.01      154.68           0.00
# 151  -13.3113       12192.00      False    226.16      229.24           0.00
#
#     sensors  geo_altitude squawk    spi  position_source
# 0      None       1592.58   None  False                0
# 1      None       1272.54   None  False                0
# 2      None      12031.98   1745  False                0
# 3      None       6774.18   None  False                0
# 4      None       9936.48   None  False                0
# ..      ...           ...    ...    ...              ...
# 147    None      11399.52   None  False                0
# 148    None      11391.90   None  False                0
# 149    None      13281.66   None  False                0
# 150    None      11399.52   None  False                0
# 151    None      12946.38   None  False                0
#
# [152 rows x 17 columns]

# %%
# chegadas
df_chegadas = pd.DataFrame(chegadas)
print("=== CHEGADAS ===")
print(df_chegadas.shape)
df_chegadas.head(200)

df_chegadas["estArrivalAirport"].unique()
# Out:
# === CHEGADAS ===
# (731, 12)
# array(['SBGR', 'SBGL', 'SBBR'], dtype=object)

# %%
# intervalo
df_intervalo = pd.DataFrame(intervalo)
print("=== INTERVALO ===")
print(df_intervalo.shape)
df_intervalo.head(200)
# Out:
# === INTERVALO ===
# (472, 12)
#      icao24   firstSeen estDepartureAirport    lastSeen estArrivalAirport  \
# 0    84630c  1517229441                None  1517230681              None
# 1    800547  1517227477                VGTJ  1517228618              None
# 2    a403ca  1517228212                None  1517229651              None
# 3    0c6018  1517227972                KJFK  1517229448              None
# 4    abc2e5  1517228209                KEWR  1517229988              None
# ..      ...         ...                 ...         ...               ...
# 195  c078fd  1517227317                CYYZ  1517230676              CYUL
# 196  8686b2  1517229296                None  1517230536              RJTK
# 197  e491f0  1517229076                None  1517230486              SBMT
# 198  3e3a2c  1517227395                EDFZ  1517228367              EDRI
# 199  4ca88c  1517227634                None  1517230768              None
#
#      callsign  estDepartureAirportHorizDistance  \
# 0    JJP120                                 NaN
# 1    JAI273                              6958.0
# 2        None                               NaN
# 3        None                            7899.0
# 4    RPA3598                             2093.0
# ..        ...                               ...
# 195  SWG9426                              525.0
# 196  JAL920                                 NaN
# 197  ONE6105                                NaN
# 198  DINFO                               2059.0
# 199  RYR55HX                                NaN
#
#      estDepartureAirportVertDistance  estArrivalAirportHorizDistance  \
# 0                                NaN                             NaN
# 1                              655.0                             NaN
# 2                                NaN                             NaN
# 3                             1161.0                             NaN
# 4                               89.0                             NaN
# ..                               ...                             ...
# 195                            104.0                          3244.0
# 196                              NaN                         15167.0
# 197                              NaN                          6467.0
# 198                            175.0                         12600.0
# 199                              NaN                             NaN
#
#      estArrivalAirportVertDistance  departureAirportCandidatesCount  \
# 0                              NaN                                0
# 1                              NaN                                1
# 2                              NaN                                0
# 3                              NaN                                0
# 4                              NaN                                1
# ..                             ...                              ...
# 195                           81.0                                1
# 196                         1421.0                                0
# 197                          566.0                                0
# 198                         1638.0                                0
# 199                            NaN                                0
#
#      arrivalAirportCandidatesCount
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ..                             ...
# 195                              1
# 196                              1
# 197                              2
# 198                              2
# 199                              0
#
# [200 rows x 12 columns]

# %%
df_partidas = pd.DataFrame(partidas)
print("===PARTIDAS===")
print(df_partidas.shape)
df_partidas.head()
# Out:
# ===PARTIDAS===
# (29, 12)
#    icao24   firstSeen estDepartureAirport    lastSeen estArrivalAirport  \
# 0  e48b65  1517230782                SBGR  1517234419              SBVT
# 1  e48f6a  1517230697                SBGR  1517241394              SBBE
# 2  e48dc1  1517230612                SBGR  1517234572              None
# 3  0d09ec  1517230461                SBGR  1517248678              None
# 4  e48618  1517230344                SBGR  1517238618              SUMU
#
#    callsign  estDepartureAirportHorizDistance  \
# 0  TAM3362                               6200
# 1  TAM3554                               6196
# 2  TAM9006                               5788
# 3  AMX015                                6071
# 4  GLO7630                               8080
#
#    estDepartureAirportVertDistance  estArrivalAirportHorizDistance  \
# 0                              355                           340.0
# 1                              363                          2019.0
# 2                              393                             NaN
# 3                              500                             NaN
# 4                              644                          4792.0
#
#    estArrivalAirportVertDistance  departureAirportCandidatesCount  \
# 0                           11.0                                0
# 1                           67.0                                0
# 2                            NaN                                0
# 3                            NaN                                0
# 4                          135.0                                0
#
#    arrivalAirportCandidatesCount
# 0                              0
# 1                              1
# 2                              0
# 3                              0
# 4                              1
